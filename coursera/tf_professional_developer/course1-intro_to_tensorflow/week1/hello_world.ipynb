# %%
import tensorflow as tf
import numpy as np

# %%
""" Define the Neural Network

This is the simplest possible Neural Network. It has 1 layer, and that layer has 1 Neuron, and the input shape to it is just 1 value.
"""
model = tf.keras.Sequential([tf.keras.layers.Dense(units=1, input_shape=[1])])

# %%
""" Compile the Neural Network

Whe we compile the Neural Network, we have to specify 2 functions: Loss and an Optimizer.

* sgd - Stochastic Gradient Descent
* mse - mean_squared_error
"""
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
""" Provide the Data """
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %%
""" Training the Neural Network """
model.fit(xs, ys, epochs=500)
# Out:
# =====] - 0s 1ms/step - loss: 0.0043
# Epoch 260/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0042
# Epoch 261/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 262/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 263/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 264/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 265/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 266/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0037
# Epoch 267/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0037
# Epoch 268/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0036
# Epoch 269/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0035
# Epoch 270/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0034
# Epoch 271/500
# ...

# %%
""" Predict with the Trained Model """
print(model.predict([10.0]))
# Out:
# [[18.984268]]

# %% [markdown]
# You might have thought 19, right? But it ended up being a little under. Why do you think that is?
#
# Remember that neural networks deal with probabilities, so given the data that we fed the NN with, it calculated that there is a very high probability that the relationship between X and Y is Y=2X-1, but with only 6 data points we can't know for sure. As a result, the result for 10 is very close to 19, but not necessarily 19.
#
# As you work with neural networks, you'll see this pattern recurring. You will almost always deal with probabilities, not certainties, and will do a little bit of coding to figure out what the result is based on the probabilities, particularly when it comes to classification.
